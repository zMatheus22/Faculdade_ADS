# %% [markdown]
# # Pontifícia Universidade Católica do Paraná
# ## Disciplina: Técnicas de Machine Learning
# #### Conteúdo complementar da Semana 6 - Pipelines e Otimização de Hiperparâmetros

# %% [markdown]
# A ideia deste notebook é a de mostrar o uso de pipelines e da otimização de hiperparâmetros para termos modelos que com um fluxo completo de transformação de dados (no caso dos pipelines) e que tenham a melhor performance possível (no caso da otimização dos hiperparâmetros). Aqui, entenda que *hiperparâmetros* são aqueles parâmetros que ficam dentro dos modelos de aprendizagem supervisionada como, por exemplo, o ```n_neighbors``` no KNN e ```n_estimators``` do random forest.
#
# Da mesma forma que comentamos nos notebooks anteriores aproveite este notebook para entender as funções e, quando tiver alguma dúvida sobre o significado de algum novo parâmetro, procurar na documentação oficial das bibliotecas para entender melhor quais são as possibilidades. Exemplo: <em>"o que significa o</em> ```sep``` <em>no pd.read.csv?"</em>

# %%
import pandas as pd # importando o pandas para manipularmos os datasets

from sklearn.model_selection import train_test_split, RandomizedSearchCV, GridSearchCV # utilizado para o split entre treinamento e teste e para a otimização de hiperparâmetros
from sklearn.ensemble import * # importando vários ensembles para que possamos testá-los posteriormente
from sklearn.pipeline import Pipeline # utilizado para criar pipelines
from sklearn.neighbors import KNeighborsClassifier # utilizado para treinar o KNN
from sklearn.linear_model import LogisticRegression # utilizado para treinar um modelo de classificação (regressão logística - apesar do nome é para problemas de classificação)
from sklearn.preprocessing import OrdinalEncoder, OneHotEncoder, RobustScaler # utilizado para converter colunas do tipo texto para numéricas
from sklearn.decomposition import PCA # utilizado para fazer o PCA nos pipelines
from sklearn.metrics import f1_score, make_scorer # utilizado para calcular a performance dos pipelines

from lightgbm import LGBMClassifier # utilizado para treinar o LightGBM

from sklearn import set_config # utilizado para mostrar os passos do pipeline de forma visual
set_config(display='diagram') # forçando para que os passos do pipeline sejam mostrados em visual

# %% [markdown]
# Utilizaremos o <a href="http://archive.ics.uci.edu/ml/datasets/Adult">adult dataset</a>. Ele contém os dados do censo populacional feito nos EUA em 1994. Traduzimos os nomes dos atributos para um melhor entendimento. O significado deles é:
#
# - *idade*: a idade da pessoa.
# - *classetrabalhadora*: a classe trabalhadora na qual aquela pessoa está inserida. Exemplos incluem: funcionário público municipal/estadual/federal; nunca trabalhou; funcionário autônomo; setor privado; sem renda.
# - *totalpessoasestimadas*: a quantidade de habitantes no qual acredita-se que esta pessoa representa. Lembre-se que o censo pode ser de uma **amostra** de pessoas. Como é uma amostra vale saber quantas pessoas ao todo uma determinada instância representaria.
# - *escolaridade*: o nível de escolaridade da pessoa.
# - *escolaridadenum*: o mesmo nível, mas convertido para uma escala numérica (similar ao uso do LabelEncoder).
# - *estadocivil*: o estado civil da pessoa. Exemplos incluem: casado, solteiro, divorciado, viúvo.
# - *cargo*: o cargo da pessoa. Exemplos incluem: suporte técnico, vendas, gerencial, forças armadas, limpeza, transportes.
# - *relacionamento*: o papel da pessoa na família. Exemplos incluem: esposa, esposo, não-casado, filho(a), não está em família.
# - *raca*: a raça da pessoa.
# - *sexo*: o sexo da pessoa.
# - *ganhocapital* e *perdacapital*: ganhos e perdas de capital da pessoa.
# - *horasporsemana*: horas trabalhadas por semana.
# - *pais*: país de origem.
# - *rendaacima50k*: é a nossa **classe**. Queremos prever se uma pessoa ganha abaixo ou acima de 50K dólares. Os valores incluem "<=50K" e ">50K".
#
# Observe que vários dados não estão em uma escala numérica. Se tentarmos rodar um ```RandomForestClassifier``` ou qualquer outro modelo teremos um erro. Logo, precisaremos primeiro tratar estas colunas antes de criar um algoritmo de aprendizagem supervisionada.

# %%
df_adult = pd.read_csv('http://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.data',
                       names=['idade', 'classetrabalhadora', 'totalpessoasestimadas', 'escolaridade',
                              'escolaridadenum', 'estadocivil', 'cargo', 'relacionamento', 'raca', 
                              'sexo', 'ganhoscapital', 'perdascapital', 'horastrabalhadasporsemana',
                              'pais', 'renda'],
                          index_col=False)

df_adult
# Out:
#        idade classetrabalhadora  totalpessoasestimadas escolaridade  \
# 0         39          State-gov                  77516    Bachelors
# 1         50   Self-emp-not-inc                  83311    Bachelors
# 2         38            Private                 215646      HS-grad
# 3         53            Private                 234721         11th
# 4         28            Private                 338409    Bachelors
# ...      ...                ...                    ...          ...
# 32556     27            Private                 257302   Assoc-acdm
# 32557     40            Private                 154374      HS-grad
# 32558     58            Private                 151910      HS-grad
# 32559     22            Private                 201490      HS-grad
# 32560     52       Self-emp-inc                 287927      HS-grad
#
#        escolaridadenum          estadocivil               cargo  \
# 0                   13        Never-married        Adm-clerical
# 1                   13   Married-civ-spouse     Exec-managerial
# 2                    9             Divorced   Handlers-cleaners
# 3                    7   Married-civ-spouse   Handlers-cleaners
# 4                   13   Married-civ-spouse      Prof-specialty
# ...                ...                  ...                 ...
# 32556               12   Married-civ-spouse        Tech-support
# 32557                9   Married-civ-spouse   Machine-op-inspct
# 32558                9              Widowed        Adm-clerical
# 32559                9        Never-married        Adm-clerical
# 32560                9   Married-civ-spouse     Exec-managerial
#
#        relacionamento    raca     sexo  ganhoscapital  perdascapital  \
# 0       Not-in-family   White     Male           2174              0
# 1             Husband   White     Male              0              0
# 2       Not-in-family   White     Male              0              0
# 3             Husband   Black     Male              0              0
# 4                Wife   Black   Female              0              0
# ...               ...     ...      ...            ...            ...
# 32556            Wife   White   Female              0              0
# 32557         Husband   White     Male              0              0
# 32558       Unmarried   White   Female              0              0
# 32559       Own-child   White     Male              0              0
# 32560            Wife   White   Female          15024              0
#
#        horastrabalhadasporsemana            pais   renda
# 0                             40   United-States   <=50K
# 1                             13   United-States   <=50K
# 2                             40   United-States   <=50K
# 3                             40   United-States   <=50K
# 4                             40            Cuba   <=50K
# ...                          ...             ...     ...
# 32556                         38   United-States   <=50K
# 32557                         40   United-States    >50K
# 32558                         40   United-States   <=50K
# 32559                         20   United-States   <=50K
# 32560                         40   United-States    >50K
#
# [32561 rows x 15 columns]

# %%
# criando uma cópia do dataset para fins de teste
df_adult_copy = df_adult.copy()

# removendo o "escolaridade" já que temos o "escolaridadenum"
df_adult_copy = df_adult_copy.drop('escolaridade', axis=1)

# split entre treinamento e teste
X_train, X_test, y_train, y_test = train_test_split(df_adult_copy.drop('renda', axis=1), # aqui informamos os atributos
                                                    df_adult_copy['renda'], # aqui informamos as labels e na mesma ordem dos atributos
                                                    test_size=0.20, # informamos a porcentagem de divisão da base. Geralmente é algo entre 20% (0.20) a 35% (0.35)
                                                    random_state=0) # aqui informamos um "seed". É um valor aleatório e usado para que alguns algoritmos iniciem de forma aleatória a sua divisão.

# %%
# convertendo todas as colunas que são do tipo texto
# o handle_unknown é usado porque podem existir valores que só existem no X_test e não no X_train
# e queremos que a conversão não retorne em um erro caso isto aconteça
encoder_df = OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1).fit(X_train)

# convertendo X_train e X_test para valores numéricos.
# não usamos o fit_transform porque precisaremos dos encoders novamente para X_test e y_test
X_train = encoder_df.transform(X_train)
X_train
# Out:
# array([[1.9000e+01, 4.0000e+00, 8.4360e+03, ..., 0.0000e+00, 3.9000e+01,
#         3.9000e+01],
#        [1.8000e+01, 4.0000e+00, 1.0730e+04, ..., 0.0000e+00, 5.3000e+01,
#         3.9000e+01],
#        [2.1000e+01, 4.0000e+00, 1.4340e+03, ..., 0.0000e+00, 4.9000e+01,
#         3.9000e+01],
#        ...,
#        [6.0000e+00, 4.0000e+00, 1.1240e+03, ..., 0.0000e+00, 3.9000e+01,
#         3.9000e+01],
#        [2.8000e+01, 2.0000e+00, 1.2074e+04, ..., 0.0000e+00, 4.4000e+01,
#         3.9000e+01],
#        [8.0000e+00, 4.0000e+00, 9.6630e+03, ..., 0.0000e+00, 4.7000e+01,
#         3.9000e+01]])

# %%
# agora, treinamos um algoritmo - usaremos o KNN como teste
clf = KNeighborsClassifier().fit(X_train, y_train)

# %%
# prevendo os resultados para o X_test
# note que precisaremos chamar os encoders novamente já que treinamos o X_train e y_train contendo somente números
X_test = encoder_df.transform(X_test)
y_pred = clf.predict(X_test)
display(f'Resultados de y_pred: {y_pred}')
# Out:
# "Resultados de y_pred: [' <=50K' ' <=50K' ' <=50K' ... ' >50K' ' <=50K' ' >50K']"

# %% [markdown]
# # Pipelines
#
# Percebeu a quantidade de passos necessários para treinar e chegar aos resultados finais? Vamos usar agora o pipeline para fazer a **mesma** coisa. Primeiramente, vamos recriar o X_train/X_test/y_train/y_test porque no passo anterior havíamos os convertido para uma escala numérica.

# %%
# criando uma cópia do dataset para fins de teste
df_adult_copy = df_adult.copy()

# removendo o "escolaridade" já que temos o "escolaridadenum"
df_adult_copy = df_adult_copy.drop('escolaridade', axis=1)

# split entre treinamento e teste
X_train, X_test, y_train, y_test = train_test_split(df_adult_copy.drop('renda', axis=1), # aqui informamos os atributos
                                                    df_adult_copy['renda'], # aqui informamos as labels e na mesma ordem dos atributos
                                                    test_size=0.20, # informamos a porcentagem de divisão da base. Geralmente é algo entre 20% (0.20) a 35% (0.35)
                                                    random_state=0) # aqui informamos um "seed". É um valor aleatório e usado para que alguns algoritmos iniciem de forma aleatória a sua divisão.

# %% [markdown]
# Agora sim, vamos para o pipeline: compare com o código anterior. Note que o encoder e o KNN ficam encapsulados dentro de um único pipeline. Fazemos **só um** ```fit``` e só um ```predict```.
#
# Observe que o pipeline sempre segue a mesma forma:
# 1. Estabelecemos dentro do ```Pipeline``` uma lista de passos.
# 2. Dentro dessa lista colocamos a **ordem** de execução: no nosso exemplo, primeiro precisamos fazer a conversão dos dados em texto para número. Só depois disso que treinaremos o KNN.
# 3. Dentro da lista adicionamos uma **tupla** (este conjunto de itens entre parênteses): uma tupla é um conjunto de um ou mais itens. Aqui, o primeiro item é sempre um nome qualquer que atribuímos a um passo e o segundo item é sempre a classe que queremos utilizar, como o ```OrdinalEncoder``` e o ```KNeighborsClassifier```.
# 4. Neste pipeline, temos **dois** passos: o primeiro passo se chama *encoder* e utiliza o ```OrdinalEncoder```. O segundo passo se chama *modelo* e chama o ```KNeighborsClassifier```. Depois de definir os passos treinamos o pipeline por inteiro utilizando o ```fit```.

# %%
pipe = Pipeline([('encoder', OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1)),
                 ('modelo', KNeighborsClassifier())]).fit(X_train, y_train)

y_pred = pipe.predict(X_test)
display(f'Resultados de y_pred: {y_pred}')

display(f'Passos do pipeline (para fins ilustrativos):')
pipe
# Out:
# "Resultados de y_pred: [' <=50K' ' <=50K' ' <=50K' ... ' >50K' ' <=50K' ' >50K']"
# 'Passos do pipeline (para fins ilustrativos):'
# Pipeline(steps=[('encoder',
#                  OrdinalEncoder(handle_unknown='use_encoded_value',
#                                 unknown_value=-1)),
#                 ('modelo', KNeighborsClassifier())])

# %% [markdown]
# Note que também podemos testar outras combinações de pipelines e/ou incluir novos passos. Exemplos:

# %%
pipe_pca = Pipeline([('encoder', OneHotEncoder(handle_unknown='ignore', sparse_output=False)),
                     ('pca', PCA(n_components=3)),
                     ('modelo', RandomForestClassifier())]).fit(X_train, y_train)

y_pred_pca = pipe_pca.predict(X_test)
display(f'Resultados de y_pred: {y_pred_pca}')

display(f'Passos do pipeline (para fins ilustrativos):')
pipe_pca
# Out:
# "Resultados de y_pred: [' <=50K' ' <=50K' ' <=50K' ... ' >50K' ' >50K' ' >50K']"
# 'Passos do pipeline (para fins ilustrativos):'
# Pipeline(steps=[('encoder',
#                  OneHotEncoder(handle_unknown='ignore', sparse_output=False)),
#                 ('pca', PCA(n_components=3)),
#                 ('modelo', RandomForestClassifier())])

# %%
pipe_rf = Pipeline([('encoder', OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1)),
                    ('modelo', RandomForestClassifier(random_state=0))]).fit(X_train, y_train)

y_pred_rf = pipe_rf.predict(X_test)
display(f'Resultados de y_pred: {y_pred_rf}')

display(f'Passos do pipeline (para fins ilustrativos):')
pipe_rf
# Out:
# "Resultados de y_pred: [' <=50K' ' <=50K' ' <=50K' ... ' >50K' ' <=50K' ' >50K']"
# 'Passos do pipeline (para fins ilustrativos):'
# Pipeline(steps=[('encoder',
#                  OrdinalEncoder(handle_unknown='use_encoded_value',
#                                 unknown_value=-1)),
#                 ('modelo', RandomForestClassifier(random_state=0))])

# %%
pipe_scaler = Pipeline([('encoder', OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1)),
                        ('scaler', RobustScaler()),
                        ('modelo', KNeighborsClassifier())]).fit(X_train, y_train)

y_pred_scaler = pipe_scaler.predict(X_test)
display(f'Resultados de y_pred_scaler: {y_pred_scaler}')

display(f'Passos do pipeline (para fins ilustrativos):')
pipe_scaler
# Out:
# "Resultados de y_pred_scaler: [' <=50K' ' <=50K' ' <=50K' ... ' >50K' ' <=50K' ' >50K']"
# 'Passos do pipeline (para fins ilustrativos):'
# Pipeline(steps=[('encoder',
#                  OrdinalEncoder(handle_unknown='use_encoded_value',
#                                 unknown_value=-1)),
#                 ('scaler', RobustScaler()),
#                 ('modelo', KNeighborsClassifier())])

# %%
pipe_lgbm = Pipeline([('encoder', OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1)),
                    ('modelo', LGBMClassifier(random_state=0))]).fit(X_train, y_train)

y_pred_lgbm = pipe_lgbm.predict(X_test)
display(f'Resultados de y_pred: {y_pred_lgbm}')

display(f'Passos do pipeline (para fins ilustrativos):')
pipe_lgbm
# Out:
# [LightGBM] [Info] Number of positive: 6246, number of negative: 19802
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.006463 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 671
# [LightGBM] [Info] Number of data points in the train set: 26048, number of used features: 13
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.239788 -> initscore=-1.153842
# [LightGBM] [Info] Start training from score -1.153842
# "Resultados de y_pred: [' <=50K' ' <=50K' ' <=50K' ... ' >50K' ' <=50K' ' >50K']"
# 'Passos do pipeline (para fins ilustrativos):'
# Pipeline(steps=[('encoder',
#                  OrdinalEncoder(handle_unknown='use_encoded_value',
#                                 unknown_value=-1)),
#                 ('modelo', LGBMClassifier(random_state=0))])

# %% [markdown]
# ## Comparando os resultados
#
# Utilizaremos o F1 score para comparar os resultados. Observe o impacto das diferentes configurações de pipelines sobre os resultados.

# %%
display(f"Resultados para o primeiro pipeline: {f1_score(y_test, y_pred, pos_label=' >50K')}")
display(f"Resultados para o segundo pipeline: {f1_score(y_test, y_pred_pca, pos_label=' >50K')}")
display(f"Resultados para o terceiro pipeline: {f1_score(y_test, y_pred_rf, pos_label=' >50K')}")
display(f"Resultados para o quarto pipeline: {f1_score(y_test, y_pred_scaler, pos_label=' >50K')}")
display(f"Resultados para o quinto pipeline: {f1_score(y_test, y_pred_lgbm, pos_label=' >50K')}")
# Out:
# 'Resultados para o primeiro pipeline: 0.46098596147567744'
# 'Resultados para o segundo pipeline: 0.573489010989011'
# 'Resultados para o terceiro pipeline: 0.6677989130434783'
# 'Resultados para o quarto pipeline: 0.6459459459459459'
# 'Resultados para o quinto pipeline: 0.7068565750248427'

# %% [markdown]
# # Otimização de hiperparâmetros
#
# A princípio o pipeline (```OrdinalEncoder``` + ```KNeighborsClassifier```) teve piores resultados. Mas será que conseguiríamos resultados melhores com ele? Existem dois principais métodos no scikit-learn para isso: o <a href="https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.RandomizedSearchCV.html#sklearn.model_selection.RandomizedSearchCV">RandomSearchCV</a> e o <a href="https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.GridSearchCV.html#sklearn.model_selection.GridSearchCV">GridSearchCV</a>.
#
# O GridSearchCV é o que chamamos de *busca exaustiva*: ele testará todas as combinações de todos os parâmetros que você informar, o que pode ser bem lento dependendo de quantas combinações existirem.
#
# O RandomSearchCV seleciona aleatoriamente algumas das combinações. É mais rápido, mas não significa necessariamente que encontrará os melhores resultados.
#
# Existem outros algoritmos de otimização de hiperparâmetros como, por exemplo, a otimização bayesiana e o halving grid search. Por outro lado, o random search e o grid search são de longe os mais conhecidos. Para fazer a otimização precisamos informar todas as combinações que gostaríamos que fossem testadas. Dessa forma:
#
# 1. Abrimos a documentação do modelo que queremos otimizar (no caso, o <a href="https://scikit-learn.org/stable/modules/generated/sklearn.neighbors.KNeighborsClassifier.html#sklearn.neighbors.KNeighborsClassifier">KNeighborsClassifier</a>)
# 2. Escolhemos quais parâmetros gostaríamos de testar (exemplos: ```n_neighbors```, ```metric```, ```weights``` e ```leaf_size```).
# 3. Escolhemos quais valores testaríamos para cada uma das combinações inserindo-as em um formato de lista.
# 4. Executamos o otimizador para o modelo que queremos otimizar.
#
# Observe o funcionamento abaixo. Se possível, teste também diferentes configurações.

# %%
# rodando o encoder antes de otimizar os hiperparâmetros
# se tentássemos otimizar *dentro* do pipeline teríamos um erro.
X_train_encoded = OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1).fit_transform(X_train)

# %%
parametros = {
    'n_neighbors': [2, 5, 10, 20],
    'metric': ['euclidean', 'manhattan', 'chebyshev'],
    'weights': ['uniform', 'distance'],
    'leaf_size': [10, 30, 50]
}

# %% [markdown]
# Observe que o random search executará mais rápido, mas testará menos alternativas. Observe também que certas combinações são mais rápidas do que outras, e que o score também pode mudar radicalmente dependendo das combinações.
#
# Finalmente, o "CV" significa cross validation, ou validação cruzada. De uma forma bem simplista ele divide a base de treinamento em cinco partes, treinando com quatro partes e avaliando com a quinta e alternando também entre todas as cinco partes. Se tiver interesse <a href="https://scikit-learn.org/stable/modules/cross_validation.html#cross-validation">você pode aprender mais sobre isto aqui</a>.

# %%
# precisaremos encontrar os melhores parâmetros deste modelo.
# o parâmetro verbose mostra o passo-a-passo da execução do random search 
# o parâmetro scoring força que gostaríamos de maximizar o F1 score. Também poderíamos usar outros critérios
# lembre que o máximo que conseguimos até agora foi um score de 0.4603
clf_random = RandomizedSearchCV(KNeighborsClassifier(), parametros, verbose=3, scoring=make_scorer(f1_score, pos_label=' >50K'))
clf_random.fit(X_train_encoded, y_train)

# mostrando o melhor modelo segundo o Grid Search
best_random_search = clf_random.best_estimator_
display('Melhor classificador segundo o Random Search: ')
display(best_random_search)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV 1/5] END leaf_size=30, metric=euclidean, n_neighbors=20, weights=uniform;, score=0.275 total time=   0.4s
# [CV 2/5] END leaf_size=30, metric=euclidean, n_neighbors=20, weights=uniform;, score=0.278 total time=   0.4s
# [CV 3/5] END leaf_size=30, metric=euclidean, n_neighbors=20, weights=uniform;, score=0.268 total time=   0.4s
# [CV 4/5] END leaf_size=30, metric=euclidean, n_neighbors=20, weights=uniform;, score=0.282 total time=   0.4s
# [CV 5/5] END leaf_size=30, metric=euclidean, n_neighbors=20, weights=uniform;, score=0.239 total time=   0.5s
# [CV 1/5] END leaf_size=10, metric=manhattan, n_neighbors=5, weights=uniform;, score=0.482 total time=   0.5s
# [CV 2/5] END leaf_size=10, metric=manhattan, n_neighbors=5, weights=uniform;, score=0.483 total time=   0.4s
# [CV 3/5] END leaf_size=10, metric=manhattan, n_neighbors=5, weights=uniform;, score=0.449 total time=   0.5s
# [CV 4/5] END leaf_size=10, metric=manhattan, n_neighbors=5, weights=uniform;, score=0.484 total time=   0.5s
# [CV 5/5] END leaf_size=10, metric=manhattan, n_neighbors=5, weights=uniform;, score=0.482 total time=   0.5s
# [CV 1/5] END leaf_size=10, metric=euclidean, n_neighbors=5, weights=uniform;, score=0.452 total time=   0.5s
# [CV 2/5] END leaf_size=10, metric=euclidean, n_neighbors=5, weights=uniform;, score=0.455 total time=   0.5s
# [CV 3/5] END leaf_size=10, metric=euclidean, n_neighbors=5, weights=uniform;, score=0.418 total time=   0.4s
# [CV 4/5] END leaf_size=10, metric=euclidean, n_neighbors=5, weights=uniform;, score=0.441 total time=   0.4s
# [CV 5/5] END leaf_size=10, metric=euclidean, n_neighbors=5, weights=uniform;, score=0.436 total time=   0.4s
# [CV 1/5] END leaf_size=10, metric=chebyshev, n_neighbors=20, weights=uniform;, score=0.243 total time=   0.4s
# [CV 2/5] END leaf_size=10, metric=chebyshev, n_neighbors=20, weights=uniform;, score=0.234 total time=   0.5s
# [CV 3/5] END leaf_size=10, metric=chebyshev, n_neighbors=20, weights=uniform;, score=0.225 total time=   0.4s
# [CV 4/5] END leaf_size=10, metric=chebyshev, n_neighbors=20, weights=uniform;, score=0.236 total time=   0.5s
# [CV 5/5] END leaf_size=10, metric=chebyshev, n_neighbors=20, weights=uniform;, score=0.224 total time=   0.4s
# [CV 1/5] END leaf_size=30, metric=manhattan, n_neighbors=20, weights=distance;, score=0.376 total time=   0.2s
# [CV 2/5] END leaf_size=30, metric=manhattan, n_neighbors=20, weights=distance;, score=0.368 total time=   0.2s
# [CV 3/5] END leaf_size=30, metric=manhattan, n_neighbors=20, weights=distance;, score=0.348 total time=   0.2s
# [CV 4/5] END leaf_size=30, metric=manhattan, n_neighbors=20, weights=distance;, score=0.401 total time=   0.2s
# [CV 5/5] END leaf_size=30, metric=manhattan, n_neighbors=20, weights=distance;, score=0.330 total time=   0.2s
# [CV 1/5] END leaf_size=50, metric=manhattan, n_neighbors=5, weights=uniform;, score=0.480 total time=   0.3s
# [CV 2/5] END leaf_size=50, metric=manhattan, n_neighbors=5, weights=uniform;, score=0.482 total time=   0.4s
# [CV 3/5] END leaf_size=50, metric=manhattan, n_neighbors=5, weights=uniform;, score=0.449 total time=   0.4s
# [CV 4/5] END leaf_size=50, metric=manhattan, n_neighbors=5, weights=uniform;, score=0.485 total time=   0.4s
# [CV 5/5] END leaf_size=50, metric=manhattan, n_neighbors=5, weights=uniform;, score=0.478 total time=   0.4s
# [CV 1/5] END leaf_size=10, metric=euclidean, n_neighbors=10, weights=distance;, score=0.433 total time=   0.2s
# [CV 2/5] END leaf_size=10, metric=euclidean, n_neighbors=10, weights=distance;, score=0.423 total time=   0.2s
# [CV 3/5] END leaf_size=10, metric=euclidean, n_neighbors=10, weights=distance;, score=0.384 total time=   0.2s
# [CV 4/5] END leaf_size=10, metric=euclidean, n_neighbors=10, weights=distance;, score=0.434 total time=   0.2s
# [CV 5/5] END leaf_size=10, metric=euclidean, n_neighbors=10, weights=distance;, score=0.406 total time=   0.2s
# [CV 1/5] END leaf_size=30, metric=manhattan, n_neighbors=10, weights=distance;, score=0.473 total time=   0.1s
# [CV 2/5] END leaf_size=30, metric=manhattan, n_neighbors=10, weights=distance;, score=0.464 total time=   0.2s
# [CV 3/5] END leaf_size=30, metric=manhattan, n_neighbors=10, weights=distance;, score=0.431 total time=   0.1s
# [CV 4/5] END leaf_size=30, metric=manhattan, n_neighbors=10, weights=distance;, score=0.457 total time=   0.2s
# [CV 5/5] END leaf_size=30, metric=manhattan, n_neighbors=10, weights=distance;, score=0.444 total time=   0.1s
# [CV 1/5] END leaf_size=50, metric=euclidean, n_neighbors=5, weights=uniform;, score=0.451 total time=   0.4s
# [CV 2/5] END leaf_size=50, metric=euclidean, n_neighbors=5, weights=uniform;, score=0.455 total time=   0.4s
# [CV 3/5] END leaf_size=50, metric=euclidean, n_neighbors=5, weights=uniform;, score=0.417 total time=   0.4s
# [CV 4/5] END leaf_size=50, metric=euclidean, n_neighbors=5, weights=uniform;, score=0.441 total time=   0.4s
# [CV 5/5] END leaf_size=50, metric=euclidean, n_neighbors=5, weights=uniform;, score=0.436 total time=   0.4s
# [CV 1/5] END leaf_size=50, metric=manhattan, n_neighbors=10, weights=distance;, score=0.475 total time=   0.2s
# [CV 2/5] END leaf_size=50, metric=manhattan, n_neighbors=10, weights=distance;, score=0.467 total time=   0.1s
# [CV 3/5] END leaf_size=50, metric=manhattan, n_neighbors=10, weights=distance;, score=0.430 total time=   0.1s
# [CV 4/5] END leaf_size=50, metric=manhattan, n_neighbors=10, weights=distance;, score=0.455 total time=   0.1s
# [CV 5/5] END leaf_size=50, metric=manhattan, n_neighbors=10, weights=distance;, score=0.441 total time=   0.1s
# 'Melhor classificador segundo o Random Search: '
# KNeighborsClassifier(leaf_size=10, metric='manhattan')

# %%
# precisaremos encontrar os melhores parâmetros deste modelo.
# o parâmetro verbose mostra o passo-a-passo da execução do grid search 
# o parâmetro scoring força que gostaríamos de maximizar o F1 score. Também poderíamos usar outros critérios
# lembre que o máximo que conseguimos até agora foi um score de 0.4603
clf_grid = GridSearchCV(KNeighborsClassifier(), parametros, verbose=3, scoring=make_scorer(f1_score, pos_label=' >50K'))
clf_grid.fit(X_train_encoded, y_train)

# mostrando o melhor modelo segundo o Grid Search
best_grid_search = clf_grid.best_estimator_
display('Melhor classificador segundo o Grid Search: ')
display(best_grid_search)
# Out:
# Fitting 5 folds for each of 72 candidates, totalling 360 fits
# [CV 1/5] END leaf_size=10, metric=euclidean, n_neighbors=2, weights=uniform;, score=0.374 total time=   0.4s
# [CV 2/5] END leaf_size=10, metric=euclidean, n_neighbors=2, weights=uniform;, score=0.367 total time=   0.4s
# [CV 3/5] END leaf_size=10, metric=euclidean, n_neighbors=2, weights=uniform;, score=0.334 total time=   0.4s
# [CV 4/5] END leaf_size=10, metric=euclidean, n_neighbors=2, weights=uniform;, score=0.396 total time=   0.5s
# [CV 5/5] END leaf_size=10, metric=euclidean, n_neighbors=2, weights=uniform;, score=0.362 total time=   0.4s
# [CV 1/5] END leaf_size=10, metric=euclidean, n_neighbors=2, weights=distance;, score=0.457 total time=   0.1s
# [CV 2/5] END leaf_size=10, metric=euclidean, n_neighbors=2, weights=distance;, score=0.456 total time=   0.1s
# [CV 3/5] END leaf_size=10, metric=euclidean, n_neighbors=2, weights=distance;, score=0.436 total time=   0.1s
# [CV 4/5] END leaf_size=10, metric=euclidean, n_neighbors=2, weights=distance;, score=0.473 total time=   0.1s
# [CV 5/5] END leaf_size=10, metric=euclidean, n_neighbors=2, weights=distance;, score=0.455 total time=   0.1s
# [CV 1/5] END leaf_size=10, metric=euclidean, n_neighbors=5, weights=uniform;, score=0.452 total time=   0.4s
# [CV 2/5] END leaf_size=10, metric=euclidean, n_neighbors=5, weights=uniform;, score=0.455 total time=   0.5s
# [CV 3/5] END leaf_size=10, metric=euclidean, n_neighbors=5, weights=uniform;, score=0.418 total time=   0.6s
# [CV 4/5] END leaf_size=10, metric=euclidean, n_neighbors=5, weights=uniform;, score=0.441 total time=   0.4s
# [CV 5/5] END leaf_size=10, metric=euclidean, n_neighbors=5, weights=uniform;, score=0.436 total time=   0.4s
# [CV 1/5] END leaf_size=10, metric=euclidean, n_neighbors=5, weights=distance;, score=0.457 total time=   0.2s
# [CV 2/5] END leaf_size=10, metric=euclidean, n_neighbors=5, weights=distance;, score=0.461 total time=   0.2s
# [CV 3/5] END leaf_size=10, metric=euclidean, n_neighbors=5, weights=distance;, score=0.436 total time=   0.2s
# [CV 4/5] END leaf_size=10, metric=euclidean, n_neighbors=5, weights=distance;, score=0.442 total time=   0.2s
# [CV 5/5] END leaf_size=10, metric=euclidean, n_neighbors=5, weights=distance;, score=0.444 total time=   0.1s
# [CV 1/5] END leaf_size=10, metric=euclidean, n_neighbors=10, weights=uniform;, score=0.358 total time=   0.5s
# [CV 2/5] END leaf_size=10, metric=euclidean, n_neighbors=10, weights=uniform;, score=0.363 total time=   0.5s
# [CV 3/5] END leaf_size=10, metric=euclidean, n_neighbors=10, weights=uniform;, score=0.337 total time=   0.5s
# [CV 4/5] END leaf_size=10, metric=euclidean, n_neighbors=10, weights=uniform;, score=0.369 total time=   0.4s
# [CV 5/5] END leaf_size=10, metric=euclidean, n_neighbors=10, weights=uniform;, score=0.330 total time=   0.4s
# [CV 1/5] END leaf_size=10, metric=euclidean, n_neighbors=10, weights=distance;, score=0.433 total time=   0.2s
# [CV 2/5] END leaf_size=10, metric=euclidean, n_neighbors=10, weights=distance;, score=0.423 total time=   0.2s
# [CV 3/5] END leaf_size=10, metric=euclidean, n_neighbors=10, weights=distance;, score=0.384 total time=   0.2s
# [CV 4/5] END leaf_size=10, metric=euclidean, n_neighbors=10, weights=distance;, score=0.434 total time=   0.2s
# [CV 5/5] END leaf_size=10, metric=euclidean, n_neighbors=10, weights=distance;, score=0.406 total time=   0.2s
# [CV 1/5] END leaf_size=10, metric=euclidean, n_neighbors=20, weights=uniform;, score=0.275 total time=   0.4s
# [CV 2/5] END leaf_size=10, metric=euclidean, n_neighbors=20, weights=uniform;, score=0.278 total time=   0.6s
# [CV 3/5] END leaf_size=10, metric=euclidean, n_neighbors=20, weights=uniform;, score=0.268 total time=   0.6s
# [CV 4/5] END leaf_size=10, metric=euclidean, n_neighbors=20, weights=uniform;, score=0.282 total time=   0.5s
# [CV 5/5] END leaf_size=10, metric=euclidean, n_neighbors=20, weights=uniform;, score=0.239 total time=   0.6s
# [CV 1/5] END leaf_size=10, metric=euclidean, n_neighbors=20, weights=distance;, score=0.354 total time=   0.2s
# [CV 2/5] END leaf_size=10, metric=euclidean, n_neighbors=20, weights=distance;, score=0.352 total time=   0.3s
# [CV 3/5] END leaf_size=10, metric=euclidean, n_neighbors=20, weights=distance;, score=0.331 total time=   0.2s
# [CV 4/5] END leaf_size=10, metric=euclidean, n_neighbors=20, weights=distance;, score=0.368 total time=   0.3s
# [CV 5/5] END leaf_size=10, metric=euclidean, n_neighbors=20, weights=distance;, score=0.319 total time=   0.2s
# [CV 1/5] END leaf_size=10, metric=manhattan, n_neighbors=2, weights=uniform;, score=0.414 total time=   0.5s
# [CV 2/5] END leaf_size=10, metric=manhattan, n_neighbors=2, weights=uniform;, score=0.408 total time=   0.6s
# [CV 3/5] END leaf_size=10, metric=manhattan, n_neighbors=2, weights=uniform;, score=0.371 total time=   0.6s
# [CV 4/5] END leaf_size=10, metric=manhattan, n_neighbors=2, weights=uniform;, score=0.410 total time=   0.6s
# [CV 5/5] END leaf_size=10, metric=manhattan, n_neighbors=2, weights=uniform;, score=0.390 total time=   0.6s
# [CV 1/5] END leaf_size=10, metric=manhattan, n_neighbors=2, weights=distance;, score=0.478 total time=   0.1s
# [CV 2/5] END leaf_size=10, metric=manhattan, n_neighbors=2, weights=distance;, score=0.477 total time=   0.1s
# [CV 3/5] END leaf_size=10, metric=manhattan, n_neighbors=2, weights=distance;, score=0.470 total time=   0.2s
# [CV 4/5] END leaf_size=10, metric=manhattan, n_neighbors=2, weights=distance;, score=0.500 total time=   0.2s
# [CV 5/5] END leaf_size=10, metric=manhattan, n_neighbors=2, weights=distance;, score=0.466 total time=   0.2s
# [CV 1/5] END leaf_size=10, metric=manhattan, n_neighbors=5, weights=uniform;, score=0.482 total time=   0.5s
# [CV 2/5] END leaf_size=10, metric=manhattan, n_neighbors=5, weights=uniform;, score=0.483 total time=   0.6s
# [CV 3/5] END leaf_size=10, metric=manhattan, n_neighbors=5, weights=uniform;, score=0.449 total time=   0.5s
# [CV 4/5] END leaf_size=10, metric=manhattan, n_neighbors=5, weights=uniform;, score=0.484 total time=   0.5s
# [CV 5/5] END leaf_size=10, metric=manhattan, n_neighbors=5, weights=uniform;, score=0.482 total time=   0.4s
# [CV 1/5] END leaf_size=10, metric=manhattan, n_neighbors=5, weights=distance;, score=0.492 total time=   0.2s
# [CV 2/5] END leaf_size=10, metric=manhattan, n_neighbors=5, weights=distance;, score=0.487 total time=   0.2s
# [CV 3/5] END leaf_size=10, metric=manhattan, n_neighbors=5, weights=distance;, score=0.463 total time=   0.2s
# [CV 4/5] END leaf_size=10, metric=manhattan, n_neighbors=5, weights=distance;, score=0.492 total time=   0.2s
# [CV 5/5] END leaf_size=10, metric=manhattan, n_neighbors=5, weights=distance;, score=0.493 total time=   0.2s
# [CV 1/5] END leaf_size=10, metric=manhattan, n_neighbors=10, weights=uniform;, score=0.393 total time=   0.4s
# [CV 2/5] END leaf_size=10, metric=manhattan, n_neighbors=10, weights=uniform;, score=0.380 total time=   0.4s
# [CV 3/5] END leaf_size=10, metric=manhattan, n_neighbors=10, weights=uniform;, score=0.361 total time=   0.4s
# [CV 4/5] END leaf_size=10, metric=manhattan, n_neighbors=10, weights=uniform;, score=0.403 total time=   0.5s
# [CV 5/5] END leaf_size=10, metric=manhattan, n_neighbors=10, weights=uniform;, score=0.352 total time=   0.5s
# [CV 1/5] END leaf_size=10, metric=manhattan, n_neighbors=10, weights=distance;, score=0.474 total time=   0.2s
# [CV 2/5] END leaf_size=10, metric=manhattan, n_neighbors=10, weights=distance;, score=0.465 total time=   0.2s
# [CV 3/5] END leaf_size=10, metric=manhattan, n_neighbors=10, weights=distance;, score=0.429 total time=   0.2s
# [CV 4/5] END leaf_size=10, metric=manhattan, n_neighbors=10, weights=distance;, score=0.456 total time=   0.3s
# [CV 5/5] END leaf_size=10, metric=manhattan, n_neighbors=10, weights=distance;, score=0.441 total time=   0.3s
# [CV 1/5] END leaf_size=10, metric=manhattan, n_neighbors=20, weights=uniform;, score=0.278 total time=   0.5s
# [CV 2/5] END leaf_size=10, metric=manhattan, n_neighbors=20, weights=uniform;, score=0.285 total time=   0.6s
# [CV 3/5] END leaf_size=10, metric=manhattan, n_neighbors=20, weights=uniform;, score=0.270 total time=   0.4s
# [CV 4/5] END leaf_size=10, metric=manhattan, n_neighbors=20, weights=uniform;, score=0.303 total time=   0.5s
# [CV 5/5] END leaf_size=10, metric=manhattan, n_neighbors=20, weights=uniform;, score=0.240 total time=   0.4s
# [CV 1/5] END leaf_size=10, metric=manhattan, n_neighbors=20, weights=distance;, score=0.379 total time=   0.2s
# [CV 2/5] END leaf_size=10, metric=manhattan, n_neighbors=20, weights=distance;, score=0.365 total time=   0.2s
# [CV 3/5] END leaf_size=10, metric=manhattan, n_neighbors=20, weights=distance;, score=0.347 total time=   0.2s
# [CV 4/5] END leaf_size=10, metric=manhattan, n_neighbors=20, weights=distance;, score=0.399 total time=   0.2s
# [CV 5/5] END leaf_size=10, metric=manhattan, n_neighbors=20, weights=distance;, score=0.335 total time=   0.2s
# [CV 1/5] END leaf_size=10, metric=chebyshev, n_neighbors=2, weights=uniform;, score=0.354 total time=   0.5s
# [CV 2/5] END leaf_size=10, metric=chebyshev, n_neighbors=2, weights=uniform;, score=0.364 total time=   0.4s
# [CV 3/5] END leaf_size=10, metric=chebyshev, n_neighbors=2, weights=uniform;, score=0.316 total time=   0.4s
# [CV 4/5] END leaf_size=10, metric=chebyshev, n_neighbors=2, weights=uniform;, score=0.364 total time=   0.4s
# [CV 5/5] END leaf_size=10, metric=chebyshev, n_neighbors=2, weights=uniform;, score=0.349 total time=   0.4s
# [CV 1/5] END leaf_size=10, metric=chebyshev, n_neighbors=2, weights=distance;, score=0.430 total time=   0.2s
# [CV 2/5] END leaf_size=10, metric=chebyshev, n_neighbors=2, weights=distance;, score=0.427 total time=   0.1s
# [CV 3/5] END leaf_size=10, metric=chebyshev, n_neighbors=2, weights=distance;, score=0.410 total time=   0.1s
# [CV 4/5] END leaf_size=10, metric=chebyshev, n_neighbors=2, weights=distance;, score=0.431 total time=   0.1s
# [CV 5/5] END leaf_size=10, metric=chebyshev, n_neighbors=2, weights=distance;, score=0.430 total time=   0.2s
# [CV 1/5] END leaf_size=10, metric=chebyshev, n_neighbors=5, weights=uniform;, score=0.419 total time=   0.4s
# [CV 2/5] END leaf_size=10, metric=chebyshev, n_neighbors=5, weights=uniform;, score=0.415 total time=   0.4s
# [CV 3/5] END leaf_size=10, metric=chebyshev, n_neighbors=5, weights=uniform;, score=0.401 total time=   0.4s
# [CV 4/5] END leaf_size=10, metric=chebyshev, n_neighbors=5, weights=uniform;, score=0.423 total time=   0.5s
# [CV 5/5] END leaf_size=10, metric=chebyshev, n_neighbors=5, weights=uniform;, score=0.424 total time=   0.4s
# [CV 1/5] END leaf_size=10, metric=chebyshev, n_neighbors=5, weights=distance;, score=0.429 total time=   0.1s
# [CV 2/5] END leaf_size=10, metric=chebyshev, n_neighbors=5, weights=distance;, score=0.426 total time=   0.1s
# [CV 3/5] END leaf_size=10, metric=chebyshev, n_neighbors=5, weights=distance;, score=0.414 total time=   0.2s
# [CV 4/5] END leaf_size=10, metric=chebyshev, n_neighbors=5, weights=distance;, score=0.440 total time=   0.1s
# [CV 5/5] END leaf_size=10, metric=chebyshev, n_neighbors=5, weights=distance;, score=0.425 total time=   0.2s
# [CV 1/5] END leaf_size=10, metric=chebyshev, n_neighbors=10, weights=uniform;, score=0.345 total time=   0.4s
# [CV 2/5] END leaf_size=10, metric=chebyshev, n_neighbors=10, weights=uniform;, score=0.341 total time=   0.5s
# [CV 3/5] END leaf_size=10, metric=chebyshev, n_neighbors=10, weights=uniform;, score=0.307 total time=   0.5s
# [CV 4/5] END leaf_size=10, metric=chebyshev, n_neighbors=10, weights=uniform;, score=0.338 total time=   0.4s
# [CV 5/5] END leaf_size=10, metric=chebyshev, n_neighbors=10, weights=uniform;, score=0.308 total time=   0.5s
# [CV 1/5] END leaf_size=10, metric=chebyshev, n_neighbors=10, weights=distance;, score=0.405 total time=   0.2s
# [CV 2/5] END leaf_size=10, metric=chebyshev, n_neighbors=10, weights=distance;, score=0.409 total time=   0.2s
# [CV 3/5] END leaf_size=10, metric=chebyshev, n_neighbors=10, weights=distance;, score=0.371 total time=   0.3s
# [CV 4/5] END leaf_size=10, metric=chebyshev, n_neighbors=10, weights=distance;, score=0.414 total time=   0.2s
# [CV 5/5] END leaf_size=10, metric=chebyshev, n_neighbors=10, weights=distance;, score=0.381 total time=   0.3s
# [CV 1/5] END leaf_size=10, metric=chebyshev, n_neighbors=20, weights=uniform;, score=0.243 total time=   0.5s
# [CV 2/5] END leaf_size=10, metric=chebyshev, n_neighbors=20, weights=uniform;, score=0.234 total time=   0.5s
# [CV 3/5] END leaf_size=10, metric=chebyshev, n_neighbors=20, weights=uniform;, score=0.225 total time=   0.4s
# [CV 4/5] END leaf_size=10, metric=chebyshev, n_neighbors=20, weights=uniform;, score=0.236 total time=   0.4s
# [CV 5/5] END leaf_size=10, metric=chebyshev, n_neighbors=20, weights=uniform;, score=0.224 total time=   0.4s
# [CV 1/5] END leaf_size=10, metric=chebyshev, n_neighbors=20, weights=distance;, score=0.343 total time=   0.2s
# [CV 2/5] END leaf_size=10, metric=chebyshev, n_neighbors=20, weights=distance;, score=0.334 total time=   0.2s
# [CV 3/5] END leaf_size=10, metric=chebyshev, n_neighbors=20, weights=distance;, score=0.320 total time=   0.2s
# [CV 4/5] END leaf_size=10, metric=chebyshev, n_neighbors=20, weights=distance;, score=0.351 total time=   0.2s
# [CV 5/5] END leaf_size=10, metric=chebyshev, n_neighbors=20, weights=distance;, score=0.321 total time=   0.1s
# [CV 1/5] END leaf_size=30, metric=euclidean, n_neighbors=2, weights=uniform;, score=0.374 total time=   0.3s
# [CV 2/5] END leaf_size=30, metric=euclidean, n_neighbors=2, weights=uniform;, score=0.367 total time=   0.4s
# [CV 3/5] END leaf_size=30, metric=euclidean, n_neighbors=2, weights=uniform;, score=0.334 total time=   0.4s
# [CV 4/5] END leaf_size=30, metric=euclidean, n_neighbors=2, weights=uniform;, score=0.396 total time=   0.4s
# [CV 5/5] END leaf_size=30, metric=euclidean, n_neighbors=2, weights=uniform;, score=0.363 total time=   0.5s
# [CV 1/5] END leaf_size=30, metric=euclidean, n_neighbors=2, weights=distance;, score=0.457 total time=   0.1s
# [CV 2/5] END leaf_size=30, metric=euclidean, n_neighbors=2, weights=distance;, score=0.456 total time=   0.1s
# [CV 3/5] END leaf_size=30, metric=euclidean, n_neighbors=2, weights=distance;, score=0.436 total time=   0.1s
# [CV 4/5] END leaf_size=30, metric=euclidean, n_neighbors=2, weights=distance;, score=0.473 total time=   0.1s
# [CV 5/5] END leaf_size=30, metric=euclidean, n_neighbors=2, weights=distance;, score=0.455 total time=   0.1s
# [CV 1/5] END leaf_size=30, metric=euclidean, n_neighbors=5, weights=uniform;, score=0.451 total time=   0.4s
# [CV 2/5] END leaf_size=30, metric=euclidean, n_neighbors=5, weights=uniform;, score=0.454 total time=   0.4s
# [CV 3/5] END leaf_size=30, metric=euclidean, n_neighbors=5, weights=uniform;, score=0.417 total time=   0.4s
# [CV 4/5] END leaf_size=30, metric=euclidean, n_neighbors=5, weights=uniform;, score=0.441 total time=   0.4s
# [CV 5/5] END leaf_size=30, metric=euclidean, n_neighbors=5, weights=uniform;, score=0.436 total time=   0.4s
# [CV 1/5] END leaf_size=30, metric=euclidean, n_neighbors=5, weights=distance;, score=0.456 total time=   0.1s
# [CV 2/5] END leaf_size=30, metric=euclidean, n_neighbors=5, weights=distance;, score=0.460 total time=   0.1s
# [CV 3/5] END leaf_size=30, metric=euclidean, n_neighbors=5, weights=distance;, score=0.435 total time=   0.1s
# [CV 4/5] END leaf_size=30, metric=euclidean, n_neighbors=5, weights=distance;, score=0.442 total time=   0.1s
# [CV 5/5] END leaf_size=30, metric=euclidean, n_neighbors=5, weights=distance;, score=0.444 total time=   0.2s
# [CV 1/5] END leaf_size=30, metric=euclidean, n_neighbors=10, weights=uniform;, score=0.357 total time=   0.4s
# [CV 2/5] END leaf_size=30, metric=euclidean, n_neighbors=10, weights=uniform;, score=0.363 total time=   0.4s
# [CV 3/5] END leaf_size=30, metric=euclidean, n_neighbors=10, weights=uniform;, score=0.337 total time=   0.4s
# [CV 4/5] END leaf_size=30, metric=euclidean, n_neighbors=10, weights=uniform;, score=0.370 total time=   0.4s
# [CV 5/5] END leaf_size=30, metric=euclidean, n_neighbors=10, weights=uniform;, score=0.330 total time=   0.4s
# [CV 1/5] END leaf_size=30, metric=euclidean, n_neighbors=10, weights=distance;, score=0.432 total time=   0.1s
# [CV 2/5] END leaf_size=30, metric=euclidean, n_neighbors=10, weights=distance;, score=0.423 total time=   0.1s
# [CV 3/5] END leaf_size=30, metric=euclidean, n_neighbors=10, weights=distance;, score=0.384 total time=   0.1s
# [CV 4/5] END leaf_size=30, metric=euclidean, n_neighbors=10, weights=distance;, score=0.434 total time=   0.2s
# [CV 5/5] END leaf_size=30, metric=euclidean, n_neighbors=10, weights=distance;, score=0.406 total time=   0.1s
# [CV 1/5] END leaf_size=30, metric=euclidean, n_neighbors=20, weights=uniform;, score=0.275 total time=   0.4s
# [CV 2/5] END leaf_size=30, metric=euclidean, n_neighbors=20, weights=uniform;, score=0.278 total time=   0.4s
# [CV 3/5] END leaf_size=30, metric=euclidean, n_neighbors=20, weights=uniform;, score=0.268 total time=   0.4s
# [CV 4/5] END leaf_size=30, metric=euclidean, n_neighbors=20, weights=uniform;, score=0.282 total time=   0.4s
# [CV 5/5] END leaf_size=30, metric=euclidean, n_neighbors=20, weights=uniform;, score=0.239 total time=   0.4s
# [CV 1/5] END leaf_size=30, metric=euclidean, n_neighbors=20, weights=distance;, score=0.354 total time=   0.2s
# [CV 2/5] END leaf_size=30, metric=euclidean, n_neighbors=20, weights=distance;, score=0.352 total time=   0.1s
# [CV 3/5] END leaf_size=30, metric=euclidean, n_neighbors=20, weights=distance;, score=0.331 total time=   0.2s
# [CV 4/5] END leaf_size=30, metric=euclidean, n_neighbors=20, weights=distance;, score=0.368 total time=   0.1s
# [CV 5/5] END leaf_size=30, metric=euclidean, n_neighbors=20, weights=distance;, score=0.319 total time=   0.1s
# [CV 1/5] END leaf_size=30, metric=manhattan, n_neighbors=2, weights=uniform;, score=0.415 total time=   0.4s
# [CV 2/5] END leaf_size=30, metric=manhattan, n_neighbors=2, weights=uniform;, score=0.406 total time=   0.4s
# [CV 3/5] END leaf_size=30, metric=manhattan, n_neighbors=2, weights=uniform;, score=0.374 total time=   0.3s
# [CV 4/5] END leaf_size=30, metric=manhattan, n_neighbors=2, weights=uniform;, score=0.409 total time=   0.3s
# [CV 5/5] END leaf_size=30, metric=manhattan, n_neighbors=2, weights=uniform;, score=0.391 total time=   0.3s
# [CV 1/5] END leaf_size=30, metric=manhattan, n_neighbors=2, weights=distance;, score=0.478 total time=   0.1s
# [CV 2/5] END leaf_size=30, metric=manhattan, n_neighbors=2, weights=distance;, score=0.478 total time=   0.1s
# [CV 3/5] END leaf_size=30, metric=manhattan, n_neighbors=2, weights=distance;, score=0.470 total time=   0.1s
# [CV 4/5] END leaf_size=30, metric=manhattan, n_neighbors=2, weights=distance;, score=0.500 total time=   0.1s
# [CV 5/5] END leaf_size=30, metric=manhattan, n_neighbors=2, weights=distance;, score=0.466 total time=   0.1s
# [CV 1/5] END leaf_size=30, metric=manhattan, n_neighbors=5, weights=uniform;, score=0.481 total time=   0.4s
# [CV 2/5] END leaf_size=30, metric=manhattan, n_neighbors=5, weights=uniform;, score=0.485 total time=   0.4s
# [CV 3/5] END leaf_size=30, metric=manhattan, n_neighbors=5, weights=uniform;, score=0.449 total time=   0.6s
# [CV 4/5] END leaf_size=30, metric=manhattan, n_neighbors=5, weights=uniform;, score=0.482 total time=   0.4s
# [CV 5/5] END leaf_size=30, metric=manhattan, n_neighbors=5, weights=uniform;, score=0.477 total time=   0.4s
# [CV 1/5] END leaf_size=30, metric=manhattan, n_neighbors=5, weights=distance;, score=0.492 total time=   0.1s
# [CV 2/5] END leaf_size=30, metric=manhattan, n_neighbors=5, weights=distance;, score=0.488 total time=   0.1s
# [CV 3/5] END leaf_size=30, metric=manhattan, n_neighbors=5, weights=distance;, score=0.463 total time=   0.1s
# [CV 4/5] END leaf_size=30, metric=manhattan, n_neighbors=5, weights=distance;, score=0.491 total time=   0.1s
# [CV 5/5] END leaf_size=30, metric=manhattan, n_neighbors=5, weights=distance;, score=0.489 total time=   0.1s
# [CV 1/5] END leaf_size=30, metric=manhattan, n_neighbors=10, weights=uniform;, score=0.393 total time=   0.4s
# [CV 2/5] END leaf_size=30, metric=manhattan, n_neighbors=10, weights=uniform;, score=0.383 total time=   0.4s
# [CV 3/5] END leaf_size=30, metric=manhattan, n_neighbors=10, weights=uniform;, score=0.362 total time=   0.5s
# [CV 4/5] END leaf_size=30, metric=manhattan, n_neighbors=10, weights=uniform;, score=0.404 total time=   0.4s
# [CV 5/5] END leaf_size=30, metric=manhattan, n_neighbors=10, weights=uniform;, score=0.353 total time=   0.4s
# [CV 1/5] END leaf_size=30, metric=manhattan, n_neighbors=10, weights=distance;, score=0.473 total time=   0.1s
# [CV 2/5] END leaf_size=30, metric=manhattan, n_neighbors=10, weights=distance;, score=0.464 total time=   0.2s
# [CV 3/5] END leaf_size=30, metric=manhattan, n_neighbors=10, weights=distance;, score=0.431 total time=   0.1s
# [CV 4/5] END leaf_size=30, metric=manhattan, n_neighbors=10, weights=distance;, score=0.457 total time=   0.1s
# [CV 5/5] END leaf_size=30, metric=manhattan, n_neighbors=10, weights=distance;, score=0.444 total time=   0.2s
# [CV 1/5] END leaf_size=30, metric=manhattan, n_neighbors=20, weights=uniform;, score=0.274 total time=   0.4s
# [CV 2/5] END leaf_size=30, metric=manhattan, n_neighbors=20, weights=uniform;, score=0.284 total time=   0.4s
# [CV 3/5] END leaf_size=30, metric=manhattan, n_neighbors=20, weights=uniform;, score=0.270 total time=   0.4s
# [CV 4/5] END leaf_size=30, metric=manhattan, n_neighbors=20, weights=uniform;, score=0.302 total time=   0.4s
# [CV 5/5] END leaf_size=30, metric=manhattan, n_neighbors=20, weights=uniform;, score=0.241 total time=   0.4s
# [CV 1/5] END leaf_size=30, metric=manhattan, n_neighbors=20, weights=distance;, score=0.376 total time=   0.2s
# [CV 2/5] END leaf_size=30, metric=manhattan, n_neighbors=20, weights=distance;, score=0.368 total time=   0.2s
# [CV 3/5] END leaf_size=30, metric=manhattan, n_neighbors=20, weights=distance;, score=0.348 total time=   0.2s
# [CV 4/5] END leaf_size=30, metric=manhattan, n_neighbors=20, weights=distance;, score=0.401 total time=   0.2s
# [CV 5/5] END leaf_size=30, metric=manhattan, n_neighbors=20, weights=distance;, score=0.330 total time=   0.2s
# [CV 1/5] END leaf_size=30, metric=chebyshev, n_neighbors=2, weights=uniform;, score=0.356 total time=   0.4s
# [CV 2/5] END leaf_size=30, metric=chebyshev, n_neighbors=2, weights=uniform;, score=0.362 total time=   0.4s
# [CV 3/5] END leaf_size=30, metric=chebyshev, n_neighbors=2, weights=uniform;, score=0.316 total time=   0.5s
# [CV 4/5] END leaf_size=30, metric=chebyshev, n_neighbors=2, weights=uniform;, score=0.365 total time=   0.5s
# [CV 5/5] END leaf_size=30, metric=chebyshev, n_neighbors=2, weights=uniform;, score=0.358 total time=   0.3s
# [CV 1/5] END leaf_size=30, metric=chebyshev, n_neighbors=2, weights=distance;, score=0.431 total time=   0.1s
# [CV 2/5] END leaf_size=30, metric=chebyshev, n_neighbors=2, weights=distance;, score=0.424 total time=   0.1s
# [CV 3/5] END leaf_size=30, metric=chebyshev, n_neighbors=2, weights=distance;, score=0.413 total time=   0.1s
# [CV 4/5] END leaf_size=30, metric=chebyshev, n_neighbors=2, weights=distance;, score=0.429 total time=   0.1s
# [CV 5/5] END leaf_size=30, metric=chebyshev, n_neighbors=2, weights=distance;, score=0.431 total time=   0.1s
# [CV 1/5] END leaf_size=30, metric=chebyshev, n_neighbors=5, weights=uniform;, score=0.413 total time=   0.5s
# [CV 2/5] END leaf_size=30, metric=chebyshev, n_neighbors=5, weights=uniform;, score=0.411 total time=   0.4s
# [CV 3/5] END leaf_size=30, metric=chebyshev, n_neighbors=5, weights=uniform;, score=0.402 total time=   0.4s
# [CV 4/5] END leaf_size=30, metric=chebyshev, n_neighbors=5, weights=uniform;, score=0.425 total time=   0.4s
# [CV 5/5] END leaf_size=30, metric=chebyshev, n_neighbors=5, weights=uniform;, score=0.425 total time=   0.4s
# [CV 1/5] END leaf_size=30, metric=chebyshev, n_neighbors=5, weights=distance;, score=0.422 total time=   0.1s
# [CV 2/5] END leaf_size=30, metric=chebyshev, n_neighbors=5, weights=distance;, score=0.421 total time=   0.1s
# [CV 3/5] END leaf_size=30, metric=chebyshev, n_neighbors=5, weights=distance;, score=0.413 total time=   0.1s
# [CV 4/5] END leaf_size=30, metric=chebyshev, n_neighbors=5, weights=distance;, score=0.444 total time=   0.1s
# [CV 5/5] END leaf_size=30, metric=chebyshev, n_neighbors=5, weights=distance;, score=0.428 total time=   0.1s
# [CV 1/5] END leaf_size=30, metric=chebyshev, n_neighbors=10, weights=uniform;, score=0.340 total time=   0.4s
# [CV 2/5] END leaf_size=30, metric=chebyshev, n_neighbors=10, weights=uniform;, score=0.338 total time=   0.4s
# [CV 3/5] END leaf_size=30, metric=chebyshev, n_neighbors=10, weights=uniform;, score=0.305 total time=   0.4s
# [CV 4/5] END leaf_size=30, metric=chebyshev, n_neighbors=10, weights=uniform;, score=0.349 total time=   0.4s
# [CV 5/5] END leaf_size=30, metric=chebyshev, n_neighbors=10, weights=uniform;, score=0.308 total time=   0.4s
# [CV 1/5] END leaf_size=30, metric=chebyshev, n_neighbors=10, weights=distance;, score=0.401 total time=   0.1s
# [CV 2/5] END leaf_size=30, metric=chebyshev, n_neighbors=10, weights=distance;, score=0.406 total time=   0.1s
# [CV 3/5] END leaf_size=30, metric=chebyshev, n_neighbors=10, weights=distance;, score=0.370 total time=   0.2s
# [CV 4/5] END leaf_size=30, metric=chebyshev, n_neighbors=10, weights=distance;, score=0.410 total time=   0.2s
# [CV 5/5] END leaf_size=30, metric=chebyshev, n_neighbors=10, weights=distance;, score=0.388 total time=   0.2s
# [CV 1/5] END leaf_size=30, metric=chebyshev, n_neighbors=20, weights=uniform;, score=0.246 total time=   0.5s
# [CV 2/5] END leaf_size=30, metric=chebyshev, n_neighbors=20, weights=uniform;, score=0.238 total time=   0.4s
# [CV 3/5] END leaf_size=30, metric=chebyshev, n_neighbors=20, weights=uniform;, score=0.221 total time=   0.4s
# [CV 4/5] END leaf_size=30, metric=chebyshev, n_neighbors=20, weights=uniform;, score=0.238 total time=   0.4s
# [CV 5/5] END leaf_size=30, metric=chebyshev, n_neighbors=20, weights=uniform;, score=0.232 total time=   0.5s
# [CV 1/5] END leaf_size=30, metric=chebyshev, n_neighbors=20, weights=distance;, score=0.341 total time=   0.2s
# [CV 2/5] END leaf_size=30, metric=chebyshev, n_neighbors=20, weights=distance;, score=0.332 total time=   0.2s
# [CV 3/5] END leaf_size=30, metric=chebyshev, n_neighbors=20, weights=distance;, score=0.312 total time=   0.2s
# [CV 4/5] END leaf_size=30, metric=chebyshev, n_neighbors=20, weights=distance;, score=0.353 total time=   0.2s
# [CV 5/5] END leaf_size=30, metric=chebyshev, n_neighbors=20, weights=distance;, score=0.315 total time=   0.2s
# [CV 1/5] END leaf_size=50, metric=euclidean, n_neighbors=2, weights=uniform;, score=0.373 total time=   0.4s
# [CV 2/5] END leaf_size=50, metric=euclidean, n_neighbors=2, weights=uniform;, score=0.367 total time=   0.4s
# [CV 3/5] END leaf_size=50, metric=euclidean, n_neighbors=2, weights=uniform;, score=0.335 total time=   0.4s
# [CV 4/5] END leaf_size=50, metric=euclidean, n_neighbors=2, weights=uniform;, score=0.397 total time=   0.4s
# [CV 5/5] END leaf_size=50, metric=euclidean, n_neighbors=2, weights=uniform;, score=0.363 total time=   0.4s
# [CV 1/5] END leaf_size=50, metric=euclidean, n_neighbors=2, weights=distance;, score=0.457 total time=   0.1s
# [CV 2/5] END leaf_size=50, metric=euclidean, n_neighbors=2, weights=distance;, score=0.456 total time=   0.1s
# [CV 3/5] END leaf_size=50, metric=euclidean, n_neighbors=2, weights=distance;, score=0.436 total time=   0.1s
# [CV 4/5] END leaf_size=50, metric=euclidean, n_neighbors=2, weights=distance;, score=0.473 total time=   0.1s
# [CV 5/5] END leaf_size=50, metric=euclidean, n_neighbors=2, weights=distance;, score=0.455 total time=   0.1s
# [CV 1/5] END leaf_size=50, metric=euclidean, n_neighbors=5, weights=uniform;, score=0.451 total time=   0.3s
# [CV 2/5] END leaf_size=50, metric=euclidean, n_neighbors=5, weights=uniform;, score=0.455 total time=   0.3s
# [CV 3/5] END leaf_size=50, metric=euclidean, n_neighbors=5, weights=uniform;, score=0.417 total time=   0.5s
# [CV 4/5] END leaf_size=50, metric=euclidean, n_neighbors=5, weights=uniform;, score=0.441 total time=   0.4s
# [CV 5/5] END leaf_size=50, metric=euclidean, n_neighbors=5, weights=uniform;, score=0.436 total time=   0.4s
# [CV 1/5] END leaf_size=50, metric=euclidean, n_neighbors=5, weights=distance;, score=0.456 total time=   0.1s
# [CV 2/5] END leaf_size=50, metric=euclidean, n_neighbors=5, weights=distance;, score=0.461 total time=   0.2s
# [CV 3/5] END leaf_size=50, metric=euclidean, n_neighbors=5, weights=distance;, score=0.435 total time=   0.1s
# [CV 4/5] END leaf_size=50, metric=euclidean, n_neighbors=5, weights=distance;, score=0.443 total time=   0.1s
# [CV 5/5] END leaf_size=50, metric=euclidean, n_neighbors=5, weights=distance;, score=0.445 total time=   0.1s
# [CV 1/5] END leaf_size=50, metric=euclidean, n_neighbors=10, weights=uniform;, score=0.357 total time=   0.4s
# [CV 2/5] END leaf_size=50, metric=euclidean, n_neighbors=10, weights=uniform;, score=0.363 total time=   0.4s
# [CV 3/5] END leaf_size=50, metric=euclidean, n_neighbors=10, weights=uniform;, score=0.337 total time=   0.4s
# [CV 4/5] END leaf_size=50, metric=euclidean, n_neighbors=10, weights=uniform;, score=0.369 total time=   0.4s
# [CV 5/5] END leaf_size=50, metric=euclidean, n_neighbors=10, weights=uniform;, score=0.330 total time=   0.4s
# [CV 1/5] END leaf_size=50, metric=euclidean, n_neighbors=10, weights=distance;, score=0.433 total time=   0.1s
# [CV 2/5] END leaf_size=50, metric=euclidean, n_neighbors=10, weights=distance;, score=0.423 total time=   0.1s
# [CV 3/5] END leaf_size=50, metric=euclidean, n_neighbors=10, weights=distance;, score=0.384 total time=   0.1s
# [CV 4/5] END leaf_size=50, metric=euclidean, n_neighbors=10, weights=distance;, score=0.434 total time=   0.1s
# [CV 5/5] END leaf_size=50, metric=euclidean, n_neighbors=10, weights=distance;, score=0.406 total time=   0.1s
# [CV 1/5] END leaf_size=50, metric=euclidean, n_neighbors=20, weights=uniform;, score=0.275 total time=   0.4s
# [CV 2/5] END leaf_size=50, metric=euclidean, n_neighbors=20, weights=uniform;, score=0.278 total time=   0.4s
# [CV 3/5] END leaf_size=50, metric=euclidean, n_neighbors=20, weights=uniform;, score=0.267 total time=   0.4s
# [CV 4/5] END leaf_size=50, metric=euclidean, n_neighbors=20, weights=uniform;, score=0.282 total time=   0.4s
# [CV 5/5] END leaf_size=50, metric=euclidean, n_neighbors=20, weights=uniform;, score=0.239 total time=   0.4s
# [CV 1/5] END leaf_size=50, metric=euclidean, n_neighbors=20, weights=distance;, score=0.354 total time=   0.1s
# [CV 2/5] END leaf_size=50, metric=euclidean, n_neighbors=20, weights=distance;, score=0.351 total time=   0.1s
# [CV 3/5] END leaf_size=50, metric=euclidean, n_neighbors=20, weights=distance;, score=0.331 total time=   0.2s
# [CV 4/5] END leaf_size=50, metric=euclidean, n_neighbors=20, weights=distance;, score=0.368 total time=   0.1s
# [CV 5/5] END leaf_size=50, metric=euclidean, n_neighbors=20, weights=distance;, score=0.319 total time=   0.2s
# [CV 1/5] END leaf_size=50, metric=manhattan, n_neighbors=2, weights=uniform;, score=0.414 total time=   0.4s
# [CV 2/5] END leaf_size=50, metric=manhattan, n_neighbors=2, weights=uniform;, score=0.404 total time=   0.4s
# [CV 3/5] END leaf_size=50, metric=manhattan, n_neighbors=2, weights=uniform;, score=0.371 total time=   0.4s
# [CV 4/5] END leaf_size=50, metric=manhattan, n_neighbors=2, weights=uniform;, score=0.412 total time=   0.4s
# [CV 5/5] END leaf_size=50, metric=manhattan, n_neighbors=2, weights=uniform;, score=0.388 total time=   0.4s
# [CV 1/5] END leaf_size=50, metric=manhattan, n_neighbors=2, weights=distance;, score=0.478 total time=   0.1s
# [CV 2/5] END leaf_size=50, metric=manhattan, n_neighbors=2, weights=distance;, score=0.478 total time=   0.1s
# [CV 3/5] END leaf_size=50, metric=manhattan, n_neighbors=2, weights=distance;, score=0.469 total time=   0.1s
# [CV 4/5] END leaf_size=50, metric=manhattan, n_neighbors=2, weights=distance;, score=0.500 total time=   0.1s
# [CV 5/5] END leaf_size=50, metric=manhattan, n_neighbors=2, weights=distance;, score=0.466 total time=   0.1s
# [CV 1/5] END leaf_size=50, metric=manhattan, n_neighbors=5, weights=uniform;, score=0.480 total time=   0.4s
# [CV 2/5] END leaf_size=50, metric=manhattan, n_neighbors=5, weights=uniform;, score=0.482 total time=   0.3s
# [CV 3/5] END leaf_size=50, metric=manhattan, n_neighbors=5, weights=uniform;, score=0.449 total time=   0.4s
# [CV 4/5] END leaf_size=50, metric=manhattan, n_neighbors=5, weights=uniform;, score=0.485 total time=   0.3s
# [CV 5/5] END leaf_size=50, metric=manhattan, n_neighbors=5, weights=uniform;, score=0.478 total time=   0.3s
# [CV 1/5] END leaf_size=50, metric=manhattan, n_neighbors=5, weights=distance;, score=0.491 total time=   0.1s
# [CV 2/5] END leaf_size=50, metric=manhattan, n_neighbors=5, weights=distance;, score=0.487 total time=   0.2s
# [CV 3/5] END leaf_size=50, metric=manhattan, n_neighbors=5, weights=distance;, score=0.461 total time=   0.1s
# [CV 4/5] END leaf_size=50, metric=manhattan, n_neighbors=5, weights=distance;, score=0.493 total time=   0.1s
# [CV 5/5] END leaf_size=50, metric=manhattan, n_neighbors=5, weights=distance;, score=0.489 total time=   0.1s
# [CV 1/5] END leaf_size=50, metric=manhattan, n_neighbors=10, weights=uniform;, score=0.396 total time=   0.4s
# [CV 2/5] END leaf_size=50, metric=manhattan, n_neighbors=10, weights=uniform;, score=0.380 total time=   0.4s
# [CV 3/5] END leaf_size=50, metric=manhattan, n_neighbors=10, weights=uniform;, score=0.363 total time=   0.4s
# [CV 4/5] END leaf_size=50, metric=manhattan, n_neighbors=10, weights=uniform;, score=0.401 total time=   0.4s
# [CV 5/5] END leaf_size=50, metric=manhattan, n_neighbors=10, weights=uniform;, score=0.350 total time=   0.4s
# [CV 1/5] END leaf_size=50, metric=manhattan, n_neighbors=10, weights=distance;, score=0.475 total time=   0.1s
# [CV 2/5] END leaf_size=50, metric=manhattan, n_neighbors=10, weights=distance;, score=0.467 total time=   0.1s
# [CV 3/5] END leaf_size=50, metric=manhattan, n_neighbors=10, weights=distance;, score=0.430 total time=   0.2s
# [CV 4/5] END leaf_size=50, metric=manhattan, n_neighbors=10, weights=distance;, score=0.455 total time=   0.1s
# [CV 5/5] END leaf_size=50, metric=manhattan, n_neighbors=10, weights=distance;, score=0.441 total time=   0.1s
# [CV 1/5] END leaf_size=50, metric=manhattan, n_neighbors=20, weights=uniform;, score=0.274 total time=   0.4s
# [CV 2/5] END leaf_size=50, metric=manhattan, n_neighbors=20, weights=uniform;, score=0.285 total time=   0.4s
# [CV 3/5] END leaf_size=50, metric=manhattan, n_neighbors=20, weights=uniform;, score=0.271 total time=   0.4s
# [CV 4/5] END leaf_size=50, metric=manhattan, n_neighbors=20, weights=uniform;, score=0.306 total time=   0.4s
# [CV 5/5] END leaf_size=50, metric=manhattan, n_neighbors=20, weights=uniform;, score=0.240 total time=   0.4s
# [CV 1/5] END leaf_size=50, metric=manhattan, n_neighbors=20, weights=distance;, score=0.372 total time=   0.2s
# [CV 2/5] END leaf_size=50, metric=manhattan, n_neighbors=20, weights=distance;, score=0.367 total time=   0.1s
# [CV 3/5] END leaf_size=50, metric=manhattan, n_neighbors=20, weights=distance;, score=0.347 total time=   0.1s
# [CV 4/5] END leaf_size=50, metric=manhattan, n_neighbors=20, weights=distance;, score=0.401 total time=   0.1s
# [CV 5/5] END leaf_size=50, metric=manhattan, n_neighbors=20, weights=distance;, score=0.334 total time=   0.2s
# [CV 1/5] END leaf_size=50, metric=chebyshev, n_neighbors=2, weights=uniform;, score=0.355 total time=   0.4s
# [CV 2/5] END leaf_size=50, metric=chebyshev, n_neighbors=2, weights=uniform;, score=0.360 total time=   0.4s
# [CV 3/5] END leaf_size=50, metric=chebyshev, n_neighbors=2, weights=uniform;, score=0.317 total time=   0.4s
# [CV 4/5] END leaf_size=50, metric=chebyshev, n_neighbors=2, weights=uniform;, score=0.375 total time=   0.4s
# [CV 5/5] END leaf_size=50, metric=chebyshev, n_neighbors=2, weights=uniform;, score=0.356 total time=   0.4s
# [CV 1/5] END leaf_size=50, metric=chebyshev, n_neighbors=2, weights=distance;, score=0.429 total time=   0.1s
# [CV 2/5] END leaf_size=50, metric=chebyshev, n_neighbors=2, weights=distance;, score=0.425 total time=   0.2s
# [CV 3/5] END leaf_size=50, metric=chebyshev, n_neighbors=2, weights=distance;, score=0.409 total time=   0.1s
# [CV 4/5] END leaf_size=50, metric=chebyshev, n_neighbors=2, weights=distance;, score=0.433 total time=   0.1s
# [CV 5/5] END leaf_size=50, metric=chebyshev, n_neighbors=2, weights=distance;, score=0.431 total time=   0.1s
# [CV 1/5] END leaf_size=50, metric=chebyshev, n_neighbors=5, weights=uniform;, score=0.408 total time=   0.4s
# [CV 2/5] END leaf_size=50, metric=chebyshev, n_neighbors=5, weights=uniform;, score=0.422 total time=   0.4s
# [CV 3/5] END leaf_size=50, metric=chebyshev, n_neighbors=5, weights=uniform;, score=0.408 total time=   0.4s
# [CV 4/5] END leaf_size=50, metric=chebyshev, n_neighbors=5, weights=uniform;, score=0.426 total time=   0.4s
# [CV 5/5] END leaf_size=50, metric=chebyshev, n_neighbors=5, weights=uniform;, score=0.421 total time=   0.3s
# [CV 1/5] END leaf_size=50, metric=chebyshev, n_neighbors=5, weights=distance;, score=0.419 total time=   0.1s
# [CV 2/5] END leaf_size=50, metric=chebyshev, n_neighbors=5, weights=distance;, score=0.428 total time=   0.1s
# [CV 3/5] END leaf_size=50, metric=chebyshev, n_neighbors=5, weights=distance;, score=0.417 total time=   0.1s
# [CV 4/5] END leaf_size=50, metric=chebyshev, n_neighbors=5, weights=distance;, score=0.441 total time=   0.1s
# [CV 5/5] END leaf_size=50, metric=chebyshev, n_neighbors=5, weights=distance;, score=0.422 total time=   0.1s
# [CV 1/5] END leaf_size=50, metric=chebyshev, n_neighbors=10, weights=uniform;, score=0.344 total time=   0.4s
# [CV 2/5] END leaf_size=50, metric=chebyshev, n_neighbors=10, weights=uniform;, score=0.333 total time=   0.4s
# [CV 3/5] END leaf_size=50, metric=chebyshev, n_neighbors=10, weights=uniform;, score=0.301 total time=   0.4s
# [CV 4/5] END leaf_size=50, metric=chebyshev, n_neighbors=10, weights=uniform;, score=0.342 total time=   0.4s
# [CV 5/5] END leaf_size=50, metric=chebyshev, n_neighbors=10, weights=uniform;, score=0.306 total time=   0.4s
# [CV 1/5] END leaf_size=50, metric=chebyshev, n_neighbors=10, weights=distance;, score=0.398 total time=   0.1s
# [CV 2/5] END leaf_size=50, metric=chebyshev, n_neighbors=10, weights=distance;, score=0.411 total time=   0.2s
# [CV 3/5] END leaf_size=50, metric=chebyshev, n_neighbors=10, weights=distance;, score=0.358 total time=   0.2s
# [CV 4/5] END leaf_size=50, metric=chebyshev, n_neighbors=10, weights=distance;, score=0.418 total time=   0.1s
# [CV 5/5] END leaf_size=50, metric=chebyshev, n_neighbors=10, weights=distance;, score=0.388 total time=   0.1s
# [CV 1/5] END leaf_size=50, metric=chebyshev, n_neighbors=20, weights=uniform;, score=0.251 total time=   0.4s
# [CV 2/5] END leaf_size=50, metric=chebyshev, n_neighbors=20, weights=uniform;, score=0.239 total time=   0.5s
# [CV 3/5] END leaf_size=50, metric=chebyshev, n_neighbors=20, weights=uniform;, score=0.224 total time=   0.4s
# [CV 4/5] END leaf_size=50, metric=chebyshev, n_neighbors=20, weights=uniform;, score=0.230 total time=   0.4s
# [CV 5/5] END leaf_size=50, metric=chebyshev, n_neighbors=20, weights=uniform;, score=0.218 total time=   0.4s
# [CV 1/5] END leaf_size=50, metric=chebyshev, n_neighbors=20, weights=distance;, score=0.339 total time=   0.2s
# [CV 2/5] END leaf_size=50, metric=chebyshev, n_neighbors=20, weights=distance;, score=0.334 total time=   0.1s
# [CV 3/5] END leaf_size=50, metric=chebyshev, n_neighbors=20, weights=distance;, score=0.312 total time=   0.2s
# [CV 4/5] END leaf_size=50, metric=chebyshev, n_neighbors=20, weights=distance;, score=0.350 total time=   0.2s
# [CV 5/5] END leaf_size=50, metric=chebyshev, n_neighbors=20, weights=distance;, score=0.316 total time=   0.1s
# 'Melhor classificador segundo o Grid Search: '
# KNeighborsClassifier(leaf_size=10, metric='manhattan', weights='distance')

# %% [markdown]
# Em alguns casos o random search poderá chegar à mesma conclusão do grid search, mas de uma forma bem mais rápida. Por outro lado, não podemos **garantir** que o random search sempre chegará à melhor solução. Neste **caso em específico** ambos não encontraram uma mesma combinação do ```KNeighborsClassifier```.
#
# Finalmente, vamos comparar os resultados:

# %%
pipe_original = Pipeline([('encoder', OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1)),
                          ('modelo', KNeighborsClassifier())]).fit(X_train, y_train)

y_pred_original = pipe_original.predict(X_test)
display(f'Resultados de y_pred: {y_pred_original}')

display(f'Passos do pipeline (para fins ilustrativos):')
pipe_original
# Out:
# "Resultados de y_pred: [' <=50K' ' <=50K' ' <=50K' ... ' >50K' ' <=50K' ' >50K']"
# 'Passos do pipeline (para fins ilustrativos):'
# Pipeline(steps=[('encoder',
#                  OrdinalEncoder(handle_unknown='use_encoded_value',
#                                 unknown_value=-1)),
#                 ('modelo', KNeighborsClassifier())])

# %%
pipe_otimizado_randomsearch = Pipeline([('encoder', OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1)),
                                        ('modelo', best_random_search)]).fit(X_train, y_train)

y_pred_otimizado_randomsearch = pipe_otimizado_randomsearch.predict(X_test)
display(f'Resultados de y_pred: {y_pred_otimizado_randomsearch}')

display(f'Passos do pipeline (para fins ilustrativos):')
pipe_otimizado_randomsearch
# Out:
# "Resultados de y_pred: [' <=50K' ' <=50K' ' <=50K' ... ' >50K' ' <=50K' ' >50K']"
# 'Passos do pipeline (para fins ilustrativos):'
# Pipeline(steps=[('encoder',
#                  OrdinalEncoder(handle_unknown='use_encoded_value',
#                                 unknown_value=-1)),
#                 ('modelo',
#                  KNeighborsClassifier(leaf_size=10, metric='manhattan'))])

# %%
pipe_otimizado_gridsearch = Pipeline([('encoder', OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1)),
                                      ('modelo', best_grid_search)]).fit(X_train, y_train)

y_pred_otimizado_gridsearch = pipe_otimizado_gridsearch.predict(X_test)
display(f'Resultados de y_pred: {y_pred_otimizado_gridsearch}')

display(f'Passos do pipeline (para fins ilustrativos):')
pipe_otimizado_gridsearch
# Out:
# "Resultados de y_pred: [' <=50K' ' <=50K' ' <=50K' ... ' >50K' ' <=50K' ' >50K']"
# 'Passos do pipeline (para fins ilustrativos):'
# Pipeline(steps=[('encoder',
#                  OrdinalEncoder(handle_unknown='use_encoded_value',
#                                 unknown_value=-1)),
#                 ('modelo',
#                  KNeighborsClassifier(leaf_size=10, metric='manhattan',
#                                       weights='distance'))])

# %%
display(f"Resultados para o pipeline original: {f1_score(y_test, y_pred_original, pos_label=' >50K')}")
display(f"Resultados para o pipeline otimizado via RandomSearchCV: {f1_score(y_test, y_pred_otimizado_randomsearch, pos_label=' >50K')}")
display(f"Resultados para o pipeline otimizado via GridSearchCV: {f1_score(y_test, y_pred_otimizado_gridsearch, pos_label=' >50K')}")
# Out:
# 'Resultados para o pipeline original: 0.46098596147567744'
# 'Resultados para o pipeline otimizado via RandomSearchCV: 0.5076820307281229'
# 'Resultados para o pipeline otimizado via GridSearchCV: 0.5192936559843034'

# %% [markdown]
# Observe que foi possível melhorar a performance. Para este caso o ```KNeighborsClassifier``` ainda não foi melhor do que os demais, mas conseguimos ter uma melhora. Em casos reais, uma melhora de 0.05 pode ser a diferença entre ter um algoritmo que a área de negócios não se sente confiante com um outro algoritmo no qual a área de negócio sente-se mais à vontade para trabalhar.
